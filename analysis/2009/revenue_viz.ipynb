# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
plt.style.use (['classic'])

# %%
# Read in Revenue Files
file_2009 = "../../datasets/subsets/revenue/rev_2009.csv"

rev_2009 = pd.read_csv(file_2009)
rev_2009 = rev_2009.set_index(['STNAME'])
rev_2009
# Out:
#                           2009_R1A      2009_R1B      2009_R1C      2009_R1D  \
# STNAME
# alabama                        NaN           NaN  1.043596e+09  5.013979e+08
# alaska                         NaN           NaN  2.272793e+08  1.933536e+08
# arizona               3.168999e+09           NaN           NaN  3.436975e+07
# arkansas              1.317525e+09  2.681742e+06           NaN  3.219282e+06
# california            1.628539e+10  6.612637e+08  1.684000e+05           NaN
# colorado              3.302064e+09  4.403222e+07           NaN           NaN
# connecticut                    NaN           NaN  5.411897e+09           NaN
# delaware              4.351921e+08           NaN           NaN           NaN
# district of columbia           NaN           NaN  3.071267e+08  1.121606e+09
# florida               1.246792e+10           NaN           NaN           NaN
# georgia               5.941227e+09  1.605890e+09  1.584215e+08           NaN
# ...

# %%
(rev_2009.sum(axis=1)/1000000000).sort_values(ascending = False).head(5)
# Out:
# STNAME
# california      79.609553
# new york        56.183968
# texas           53.627433
# illinois        29.182324
# pennsylvania    27.631155
# dtype: float64

# %%
summary_2009= pd.DataFrame(rev_2009.sum(axis=1)/1000000000, columns=['Total Revenue ($B)'])
summary_2009
# Out:
#                       Total Revenue ($B)
# STNAME
# alabama                         7.786925
# alaska                          2.263099
# arizona                        10.684700
# arkansas                        5.160154
# california                     79.609553
# colorado                        9.194323
# connecticut                    10.727831
# delaware                        1.964546
# district of columbia            1.655772
# florida                        27.428238
# georgia                        18.474083
# hawaii                          2.659101
# idaho                           2.400124
# illinois                       29.182324
# indiana                        12.848629
# iowa                            6.662784
# kansas                          6.972435
# kentucky                        7.395677
# louisiana                       9.323405
# maine                           2.739718
# maryland                       13.269989
# massachusetts                  15.284951
# ...

# %%
summary_2009['Local Revenue ($B)'] = rev_2009.iloc[:,0:14].sum(axis=1)/1000000000
summary_2009
# Out:
#                       Total Revenue ($B)  Local Revenue ($B)
# STNAME
# alabama                         7.786925            2.265328
# alaska                          2.263099            0.488491
# arizona                        10.684700            4.019164
# arkansas                        5.160154            1.583494
# california                     79.609553           21.213344
# colorado                        9.194323            4.096162
# connecticut                    10.727831            5.790100
# delaware                        1.964546            0.576219
# district of columbia            1.655772            1.475283
# florida                        27.428238           14.586831
# georgia                        18.474083            8.552872
# hawaii                          2.659101            0.091241
# idaho                           2.400124            0.505150
# illinois                       29.182324           16.494552
# ...

# %%
summary_2009['State Revenue ($B)'] = rev_2009.iloc[:,15:16].sum(axis=1)/1000000000
summary_2009
# Out:
#                       Total Revenue ($B)  Local Revenue ($B)  \
# STNAME
# alabama                         7.786925            2.265328
# alaska                          2.263099            0.488491
# arizona                        10.684700            4.019164
# arkansas                        5.160154            1.583494
# california                     79.609553           21.213344
# colorado                        9.194323            4.096162
# connecticut                    10.727831            5.790100
# delaware                        1.964546            0.576219
# district of columbia            1.655772            1.475283
# florida                        27.428238           14.586831
# georgia                        18.474083            8.552872
# hawaii                          2.659101            0.091241
# idaho                           2.400124            0.505150
# illinois                       29.182324           16.494552
# ...

# %%
summary_2009['Federal Revenue ($B)'] = rev_2009.iloc[:,16:20].sum(axis=1)/1000000000
summary_2009
# Out:
#                       Total Revenue ($B)  Local Revenue ($B)  \
# STNAME
# alabama                         7.786925            2.265328
# alaska                          2.263099            0.488491
# arizona                        10.684700            4.019164
# arkansas                        5.160154            1.583494
# california                     79.609553           21.213344
# colorado                        9.194323            4.096162
# connecticut                    10.727831            5.790100
# delaware                        1.964546            0.576219
# district of columbia            1.655772            1.475283
# florida                        27.428238           14.586831
# georgia                        18.474083            8.552872
# hawaii                          2.659101            0.091241
# idaho                           2.400124            0.505150
# illinois                       29.182324           16.494552
# ...

# %%
summary_2009['Other Revenue ($B)'] = (rev_2009.iloc[:,14:15].sum(axis=1) + rev_2009.iloc[:,20:21].sum(axis=1))/1000000000
summary_2009
# Out:
#                       Total Revenue ($B)  Local Revenue ($B)  \
# STNAME
# alabama                         7.786925            2.265328
# alaska                          2.263099            0.488491
# arizona                        10.684700            4.019164
# arkansas                        5.160154            1.583494
# california                     79.609553           21.213344
# colorado                        9.194323            4.096162
# connecticut                    10.727831            5.790100
# delaware                        1.964546            0.576219
# district of columbia            1.655772            1.475283
# florida                        27.428238           14.586831
# georgia                        18.474083            8.552872
# hawaii                          2.659101            0.091241
# idaho                           2.400124            0.505150
# illinois                       29.182324           16.494552
# ...

# %%
summary_pct = pd.DataFrame(summary_2009['Local Revenue ($B)'] / summary_2009['Total Revenue ($B)'] *100, columns = ['Local Rev (%)'])
summary_pct['State Rev (%)'] = summary_2009['State Revenue ($B)'] / summary_2009['Total Revenue ($B)'] *100
summary_pct['Federal Rev (%)'] = summary_2009['Federal Revenue ($B)'] / summary_2009['Total Revenue ($B)'] *100
summary_pct['Other Rev (%)'] = summary_2009['Other Revenue ($B)'] / summary_2009['Total Revenue ($B)'] *100
summary_pct
# Out:
#                       Local Rev (%)  State Rev (%)  Federal Rev (%)  \
# STNAME
# alabama                   29.091436      53.500163         9.985849
# alaska                    21.585058      64.498221        13.916721
# arizona                   37.616070      43.318210        10.895948
# arkansas                  30.686948      52.019947        10.784564
# california                26.646732      51.006332        11.537899
# colorado                  44.550987      39.918548         6.289018
# connecticut               53.972702      35.815043         4.109183
# delaware                  29.330884      55.733446         7.249912
# district of columbia      89.099397       0.000000        10.613270
# florida                   53.181802      32.986399         9.824104
# georgia                   46.296599      42.116973         9.138609
# hawaii                     3.431276      82.923935        11.490725
# idaho                     21.046851      62.905736         9.547682
# ...

# %%
# Load in Dropout Rates
dropout_path = "../../datasets/subsets/success/success_df_2009.csv"

success_2009 = pd.read_csv(dropout_path)
success_2009
# Out:
#                   STNAME  2009_DRP912  2009_DRP9  2009_DRP10  2009_DRP11  \
# 0                alabama     1.500000   1.299999    1.599999    1.700000
# 1                 alaska     7.000000   3.699999    5.399998    9.399994
# 2                arizona     8.299995   8.000000    6.299999    7.899998
# 3               arkansas     4.099998   2.299999    3.699999    5.199997
# 4             california     5.000000   2.500000    3.000000    4.099998
# 5               colorado     6.099998   4.099998    4.500000    6.299999
# 6            connecticut     3.099998   2.699999    2.799999    3.299999
# 7               delaware     5.099998   6.099998    5.299999    4.399998
# 8   district of columbia     7.000000   8.099998    5.899998    4.199997
# 9                florida     2.599998   2.400000    2.599998    2.699999
# 10               georgia     4.199997   4.500000    4.599998    4.299999
# 11                hawaii     4.899998   3.500000    5.399998    5.299999
# ...

# %%
summary_pct['Dropout Rate'] = ''

for i in range(len(success_2009)):
    summary_pct['Dropout Rate'][i] = success_2009['2009_DRP912'][i].astype(float)
    
summary_pct
# Out:
# C:\Users\abiga\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                       Local Rev (%)  State Rev (%)  Federal Rev (%)  \
# STNAME
# alabama                   29.091436      53.500163         9.985849
# alaska                    21.585058      64.498221        13.916721
# arizona                   37.616070      43.318210        10.895948
# arkansas                  30.686948      52.019947        10.784564
# california                26.646732      51.006332        11.537899
# colorado                  44.550987      39.918548         6.289018
# connecticut               53.972702      35.815043         4.109183
# ...

# %%
summary_pct.sort_values(by=['Dropout Rate'], ascending = False)
# Out:
#                       Local Rev (%)  State Rev (%)  Federal Rev (%)  \
# STNAME
# illinois                  56.522408      25.099954        10.783036
# arizona                   37.616070      43.318210        10.895948
# alaska                    21.585058      64.498221        13.916721
# district of columbia      89.099397       0.000000        10.613270
# louisiana                 33.234852      40.116908        13.557893
# colorado                  44.550987      39.918548         6.289018
# north carolina            24.365878      58.226481         9.744895
# nevada                    56.256659      28.864802         9.207165
# delaware                  29.330884      55.733446         7.249912
# california                26.646732      51.006332        11.537899
# montana                   30.228266      47.524188        12.218345
# hawaii                     3.431276      82.923935        11.490725
# new mexico                13.023009      61.032480        12.978872
# ...

# %%
summary_2009['Dropout Rate'] = ''

for i in range(len(success_2009)):
    summary_2009['Dropout Rate'][i] = success_2009['2009_DRP912'][i].astype(float)
    
summary_2009 = summary_2009[summary_2009['Dropout Rate'].notna()]
summary_2009['Dropout Rate'] = summary_2009['Dropout Rate'].astype(float)
summary_2009.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, alabama to wyoming
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Total Revenue ($B)    51 non-null     float64
#  1   Local Revenue ($B)    51 non-null     float64
#  2   State Revenue ($B)    51 non-null     float64
#  3   Federal Revenue ($B)  51 non-null     float64
#  4   Other Revenue ($B)    51 non-null     float64
#  5   Dropout Rate          51 non-null     float64
# dtypes: float64(6)
# memory usage: 2.8+ KB
# C:\Users\abiga\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Total Revenue v Dropout

x_values = summary_2009['Total Revenue ($B)']
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('Total Revenue ($B)')
plt.ylabel('Dropout Rate (%)')
plt.title('Total Revenue vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 90)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is 0.1041

# %%
# Local Revenue v Dropout

x_values = summary_2009['Local Revenue ($B)']
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('Local Revenue ($B)')
plt.ylabel('Dropout Rate (%)')
plt.title('Local Revenue vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 30)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is 0.1016

# %%
x_values = summary_2009['State Revenue ($B)']
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('State Revenue ($B)')
plt.ylabel('Dropout Rate (%)')
plt.title('State Revenue vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 50)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is 0.0653

# %%
x_values = summary_2009['Federal Revenue ($B)']
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('Federal Revenue ($B)')
plt.ylabel('Dropout Rate (%)')
plt.title('Federal Revenue vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 10)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is 0.1873

# %%
summary_pct['Dropout Rate'] = ''

for i in range(len(success_2009)):
    summary_pct['Dropout Rate'][i] = success_2009['2009_DRP912'][i].astype(float)
    
summary_pct = summary_pct[summary_pct['Dropout Rate'].notna()]
summary_pct['Dropout Rate'] = summary_pct['Dropout Rate'].astype(float)
summary_pct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, alabama to wyoming
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Local Rev (%)    51 non-null     float64
#  1   State Rev (%)    51 non-null     float64
#  2   Federal Rev (%)  51 non-null     float64
#  3   Other Rev (%)    51 non-null     float64
#  4   Dropout Rate     51 non-null     float64
# dtypes: float64(5)
# memory usage: 2.4+ KB
# C:\Users\abiga\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
x_values = summary_pct["Local Rev (%)"]
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('Local Rev (%)')
plt.ylabel('Dropout Rate (%)')
plt.title('Local Revenue (%) vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 100)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is 0.0572

# %%
x_values = summary_pct["State Rev (%)"]
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('State Rev (%)')
plt.ylabel('Dropout Rate (%)')
plt.title('State Revenue (%) vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 100)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is -0.1384

# %%
x_values = summary_pct["Federal Rev (%)"]
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('Federal Rev (%)')
plt.ylabel('Dropout Rate (%)')
plt.title('Federal Revenue (%) vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 20)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is 0.3119

# %%
x_values = summary_pct["Other Rev (%)"]
y_values = summary_2009['Dropout Rate'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,1.5),fontsize=15,color="red")
plt.xlabel('Other Rev (%)')
plt.ylabel('Dropout Rate (%)')
plt.title('Other Revenue (%) vs Dropout Rate at the State Level')
plt.xlim(left = 0, right = 20)
plt.grid()
plt.show()
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")
# Out:
# The correlation between both factors is 0.0243
